# %% [markdown]
# # 1. MLP

# %% [markdown]
# ## 1.1. Mạng thần kinh nơ ron
#
# ![](https://appliedgo.net/media/perceptron/neuron.png)
#
# Não bộ sẽ xử lý thông tin như thế nào ?
#
# Các tín hiệu đầu vào sẽ được truyền qua dendrites, nhân của mạng nơ ron là nucles làm nhiệm vụ tổng hợp thông tin từ dendrites, sau đó lan truyền thông tin qua các axon và sau cùng thông tin output được truyền ra ở axon terminals.
#
# Kiến trúc mạng thần kinh nơ ron là khởi nguồn thiết kế cho kiến trúc mạng nơ ron.

# %% [markdown]
# ## 1.2. Kiến trúc của mạng nơ ron
#
# ![](https://machinelearningcoban.com/assets/14_mlp/multi_layers.png)
#
# Các tín hiệu đầu vào được truyền vào Input layer, mỗi một node hình tròn được gọi là unit và được coi như biến đầu vào.
#
# Sau đó dữ liệu tiếp tục được truyền qua các hidden layers để biến đổi thông tin và đưa ra quyết định ở output layer.
#
# Với một mạng nơ ron chúng ta có thể thiết kế bao nhiêu hidden layers tùy ý và số lượng các unit ở mỗi layer cũng được thay đổi tùy ý.

# %% [markdown]
# ## 1.3 Activation function
#
# Từ hình vẽ ta có thể thấy, mỗi một unit ở một hidden layer sẽ được kết nối toàn bộ tới những thông tin ở layer trước đó. Các liên kết này là tổ hợp tuyến tính:
#
# ![](https://machinelearningcoban.com/assets/14_mlp/mlp_notation.png)
#
# Ví dụ giả sử đầu vào là các unit $a_i^{(l-1)}$ của layer trước (layer thứ $l-1$). Giá trị của layer $l$ sẽ là:
#
# $$\begin{eqnarray}
# z_j & = & b_0 + w_1*a_1^{(l-1)} + \dots + w_n*a_n^{(l-1)} \\
#  & = & b_0 + {\mathbf{w}_{j}^{(l)}}^\intercal{}\mathbf{a}^{(l-1)}
# \end{eqnarray}$$
#
# Như vậy với một mạng nơ ron chúng ta có thể tạo ra vô số các features dựa vào những biến đổi tuyến tính ngẫu nhiên.
#
# Tuy nhiên nếu **chỉ áp dụng** các biến đổi tuyến tính thì kết quả cuối cùng sẽ đơn thuần là một phương trình tuyến tính của những input.
#
# Lúc này Activation sẽ đóng vai trò như các hàm biến đổi phi tuyến để thay đổi tính chất tuyến tính đơn thuần của dữ liệu. Vai trò của activation rất quan trọng đối với một mô hình mạng nơ ron, nó có tác dụng như một bộ _kích hoạt_ các thay đổi bên trong từ _tuyến tính_ sang _phi tuyến_ nên nó được gọi là activation function.
#
#
# Các hàm activation chủ yếu.
#
# ![](https://dwaithe.github.io/images/activationFunctions.png)

# %% [markdown]
# ## 1.4. Thực hành huấn luyện Model
#
# Ngày nay, các mạng nơ ron được huấn luyện rất dễ dàng nhờ sự hỗ trợ của các framework deep learning cực mạnh. Chỉ một vài dòng code chúng ta có thể tạo và huấn luyện được một mạng nơ ron theo ý muốn. Các bước huấn luyện một mạng nơ ron sẽ như sau:
#
# * Khởi tạo kiến trúc: Chúng ta sẽ phải khai báo đâu là input layer, hidden layers và output layer. Sắp xếp chồng lấn các layers này theo thứ tự để  output của layer trước là input cho layer sau.
#
# * Khai báo loss function: Hàm loss function chính là mục tiêu để chúng ta tối thiểu hóa. Mô hình sẽ càng tốt nếu loss function của nó càng nhỏ. Loss function phổ biến đối với classification là `categorical_crossentropy` cho nhiều hơn 2 nhãn hoặc `binary_categorical_crossentropy` cho 2 nhãn. Hàm loss function là `MSE` được áp dungj cho các bài toán prediction.
#
# * Khai báo optimizer: Tối ưu loss function sẽ dựa trên phương pháp gradient descent. Có nhiều kỹ thuật khác nhau để cập nhật gradient descent và optimizer là việc chúng ta khai báo sử dụng phươn pháp cập nhật gradient descent nào với bộ dữ liệu của chúng ta.
#
# * Huấn luyện mô hình: Chúng ta sẽ huấn luyện trên bao nhiêu lượt? Mỗi lượt với batch size là bao nhiêu? Tập train là gì và validation là gì? Chỉ số nào được tracking trong suốt quá trình huấn luyện mô hình ?
#
# Bên dưới chúng ta sẽ lần lượt thực hiện các bước này để xây dựng mô hình classification trên bộ dữ liệu iris.

# %%
import tensorflow as tf
import pandas as pd
import os
from sklearn import datasets
from sklearn.model_selection import train_test_split

# Download dữ liệu
iris = datasets.load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.33, random_state=42)

# %%
# Khởi tạo kiến trúc
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam

inpt = Input(shape = (4))
hidden_1 = Dense(10)(inpt)
act1 = Activation('relu')(hidden_1)
hidden_2 = Dense(10)(act1)
act2 = Activation('relu')(hidden_2)
hidden_3 = Dense(3)(act2)
output = Activation('softmax')(hidden_3)
model = Model(inputs = [inpt], outputs = [output])
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 4)]               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                50
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                110
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 33
# _________________________________________________________________
# activation_4 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Khai baos loss function vaf khowi taoj optimizer
opt = Adam()
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Huaan luyen model
model.fit(X_train, y_train,
          validation_data = (X_test, y_test),
          epochs = 100,
          batch_size = 8)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 9ms/step - loss: 1.4003 - accuracy: 0.3100 - val_loss: 1.1584 - val_accuracy: 0.3800
# Epoch 2/100
# 13/13 [==============================] - 0s 4ms/step - loss: 1.1649 - accuracy: 0.4300 - val_loss: 1.0068 - val_accuracy: 0.7000
# Epoch 3/100
# 13/13 [==============================] - 0s 4ms/step - loss: 1.0228 - accuracy: 0.6500 - val_loss: 0.9247 - val_accuracy: 0.7000
# Epoch 4/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.9468 - accuracy: 0.6500 - val_loss: 0.8740 - val_accuracy: 0.7000
# Epoch 5/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.8936 - accuracy: 0.6500 - val_loss: 0.8339 - val_accuracy: 0.7000
# Epoch 6/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.8576 - accuracy: 0.6500 - val_loss: 0.8030 - val_accuracy: 0.7000
# Epoch 7/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.8293 - accuracy: 0.6500 - val_loss: 0.7719 - val_accuracy: 0.7000
# Epoch 8/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7992 - accuracy: 0.6500 - val_loss: 0.7404 - val_accuracy: 0.7000
# Epoch 9/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7742 - accuracy: 0.6500 - val_loss: 0.7113 - val_accuracy: 0.7000
# Epoch 10/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7511 - accuracy: 0.6500 - val_loss: 0.6885 - val_accuracy: 0.7000
# Epoch 11/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7285 - accuracy: 0.6500 - val_loss: 0.6644 - val_accuracy: 0.7000
# Epoch 12/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7075 - accuracy: 0.6500 - val_loss: 0.6439 - val_accuracy: 0.7000
# Epoch 13/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6904 - accuracy: 0.6100 - val_loss: 0.6265 - val_accuracy: 0.6200
# Epoch 14/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6725 - accuracy: 0.5800 - val_loss: 0.6084 - val_accuracy: 0.6200
# Epoch 15/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6563 - accuracy: 0.5400 - val_loss: 0.5932 - val_accuracy: 0.5600
# Epoch 16/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6414 - accuracy: 0.4900 - val_loss: 0.5784 - val_accuracy: 0.5200
# Epoch 17/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6280 - accuracy: 0.5000 - val_loss: 0.5651 - val_accuracy: 0.5800
# Epoch 18/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6173 - accuracy: 0.4100 - val_loss: 0.5535 - val_accuracy: 0.5000
# Epoch 19/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6055 - accuracy: 0.5100 - val_loss: 0.5418 - val_accuracy: 0.6000
# Epoch 20/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5945 - accuracy: 0.5700 - val_loss: 0.5323 - val_accuracy: 0.6200
# Epoch 21/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5852 - accuracy: 0.5800 - val_loss: 0.5238 - val_accuracy: 0.6200
# Epoch 22/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5775 - accuracy: 0.5700 - val_loss: 0.5161 - val_accuracy: 0.6200
# Epoch 23/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5693 - accuracy: 0.5900 - val_loss: 0.5093 - val_accuracy: 0.6200
# Epoch 24/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5633 - accuracy: 0.5500 - val_loss: 0.5027 - val_accuracy: 0.6600
# Epoch 25/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5571 - accuracy: 0.6200 - val_loss: 0.4967 - val_accuracy: 0.7000
# Epoch 26/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5509 - accuracy: 0.6200 - val_loss: 0.4920 - val_accuracy: 0.7000
# Epoch 27/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5456 - accuracy: 0.5900 - val_loss: 0.4872 - val_accuracy: 0.6800
# Epoch 28/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5409 - accuracy: 0.5900 - val_loss: 0.4826 - val_accuracy: 0.7000
# Epoch 29/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5364 - accuracy: 0.6300 - val_loss: 0.4786 - val_accuracy: 0.7000
# Epoch 30/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5328 - accuracy: 0.6000 - val_loss: 0.4754 - val_accuracy: 0.6800
# Epoch 31/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5289 - accuracy: 0.5900 - val_loss: 0.4719 - val_accuracy: 0.7000
# Epoch 32/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5256 - accuracy: 0.6300 - val_loss: 0.4687 - val_accuracy: 0.7000
# Epoch 33/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5223 - accuracy: 0.6200 - val_loss: 0.4658 - val_accuracy: 0.7000
# Epoch 34/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5189 - accuracy: 0.6400 - val_loss: 0.4629 - val_accuracy: 0.7000
# Epoch 35/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5164 - accuracy: 0.6500 - val_loss: 0.4602 - val_accuracy: 0.7000
# Epoch 36/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5139 - accuracy: 0.6500 - val_loss: 0.4580 - val_accuracy: 0.7000
# Epoch 37/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5111 - accuracy: 0.6400 - val_loss: 0.4558 - val_accuracy: 0.7000
# Epoch 38/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5089 - accuracy: 0.6400 - val_loss: 0.4538 - val_accuracy: 0.7000
# Epoch 39/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5066 - accuracy: 0.6500 - val_loss: 0.4516 - val_accuracy: 0.7000
# Epoch 40/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5045 - accuracy: 0.6500 - val_loss: 0.4499 - val_accuracy: 0.7000
# Epoch 41/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5026 - accuracy: 0.6500 - val_loss: 0.4480 - val_accuracy: 0.7000
# Epoch 42/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5013 - accuracy: 0.6500 - val_loss: 0.4461 - val_accuracy: 0.7000
# Epoch 43/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5006 - accuracy: 0.6500 - val_loss: 0.4448 - val_accuracy: 0.7000
# Epoch 44/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4992 - accuracy: 0.6500 - val_loss: 0.4424 - val_accuracy: 0.7000
# Epoch 45/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4949 - accuracy: 0.6500 - val_loss: 0.4406 - val_accuracy: 0.7000
# Epoch 46/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4935 - accuracy: 0.6500 - val_loss: 0.4385 - val_accuracy: 0.7000
# Epoch 47/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4914 - accuracy: 0.6500 - val_loss: 0.4364 - val_accuracy: 0.7000
# Epoch 48/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4908 - accuracy: 0.6500 - val_loss: 0.4338 - val_accuracy: 0.7000
# Epoch 49/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4848 - accuracy: 0.6500 - val_loss: 0.4315 - val_accuracy: 0.7000
# Epoch 50/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4823 - accuracy: 0.6700 - val_loss: 0.4289 - val_accuracy: 0.7000
# Epoch 51/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4792 - accuracy: 0.6800 - val_loss: 0.4259 - val_accuracy: 0.7000
# Epoch 52/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4761 - accuracy: 0.6800 - val_loss: 0.4228 - val_accuracy: 0.7400
# Epoch 53/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4737 - accuracy: 0.7300 - val_loss: 0.4192 - val_accuracy: 0.7800
# Epoch 54/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4676 - accuracy: 0.7300 - val_loss: 0.4143 - val_accuracy: 0.7400
# Epoch 55/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4632 - accuracy: 0.7200 - val_loss: 0.4082 - val_accuracy: 0.7800
# Epoch 56/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4562 - accuracy: 0.8400 - val_loss: 0.4015 - val_accuracy: 0.8600
# Epoch 57/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4491 - accuracy: 0.8800 - val_loss: 0.3937 - val_accuracy: 0.8800
# Epoch 58/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4405 - accuracy: 0.8900 - val_loss: 0.3867 - val_accuracy: 0.9800
# Epoch 59/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4329 - accuracy: 0.9300 - val_loss: 0.3793 - val_accuracy: 0.9800
# Epoch 60/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4243 - accuracy: 0.8900 - val_loss: 0.3720 - val_accuracy: 0.9200
# Epoch 61/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4154 - accuracy: 0.9100 - val_loss: 0.3632 - val_accuracy: 0.9800
# Epoch 62/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.9600 - val_loss: 0.3552 - val_accuracy: 0.9800
# Epoch 63/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3984 - accuracy: 0.9600 - val_loss: 0.3476 - val_accuracy: 0.9800
# Epoch 64/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3909 - accuracy: 0.9700 - val_loss: 0.3402 - val_accuracy: 0.9800
# Epoch 65/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3822 - accuracy: 0.9800 - val_loss: 0.3330 - val_accuracy: 1.0000
# Epoch 66/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3734 - accuracy: 0.9600 - val_loss: 0.3250 - val_accuracy: 0.9800
# Epoch 67/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3641 - accuracy: 0.9600 - val_loss: 0.3164 - val_accuracy: 0.9800
# Epoch 68/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3565 - accuracy: 0.9700 - val_loss: 0.3081 - val_accuracy: 1.0000
# Epoch 69/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3461 - accuracy: 0.9700 - val_loss: 0.2998 - val_accuracy: 0.9800
# Epoch 70/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3385 - accuracy: 0.9600 - val_loss: 0.2918 - val_accuracy: 0.9800
# Epoch 71/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3302 - accuracy: 0.9800 - val_loss: 0.2838 - val_accuracy: 1.0000
# Epoch 72/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3212 - accuracy: 0.9700 - val_loss: 0.2760 - val_accuracy: 0.9800
# Epoch 73/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3132 - accuracy: 0.9700 - val_loss: 0.2683 - val_accuracy: 1.0000
# Epoch 74/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3027 - accuracy: 0.9700 - val_loss: 0.2599 - val_accuracy: 0.9800
# Epoch 75/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2959 - accuracy: 0.9700 - val_loss: 0.2522 - val_accuracy: 0.9800
# Epoch 76/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2880 - accuracy: 0.9700 - val_loss: 0.2451 - val_accuracy: 0.9800
# Epoch 77/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2855 - accuracy: 0.9700 - val_loss: 0.2411 - val_accuracy: 0.9800
# Epoch 78/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2708 - accuracy: 0.9800 - val_loss: 0.2302 - val_accuracy: 0.9800
# Epoch 79/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2645 - accuracy: 0.9700 - val_loss: 0.2236 - val_accuracy: 0.9800
# Epoch 80/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2552 - accuracy: 0.9800 - val_loss: 0.2198 - val_accuracy: 0.9800
# Epoch 81/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2490 - accuracy: 0.9800 - val_loss: 0.2105 - val_accuracy: 0.9800
# Epoch 82/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2417 - accuracy: 0.9700 - val_loss: 0.2050 - val_accuracy: 0.9800
# Epoch 83/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2356 - accuracy: 0.9700 - val_loss: 0.2007 - val_accuracy: 0.9600
# Epoch 84/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2282 - accuracy: 0.9800 - val_loss: 0.1930 - val_accuracy: 0.9800
# Epoch 85/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2231 - accuracy: 0.9700 - val_loss: 0.1879 - val_accuracy: 0.9800
# Epoch 86/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2177 - accuracy: 0.9900 - val_loss: 0.1865 - val_accuracy: 0.9800
# Epoch 87/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2123 - accuracy: 0.9700 - val_loss: 0.1769 - val_accuracy: 0.9800
# Epoch 88/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2045 - accuracy: 0.9800 - val_loss: 0.1786 - val_accuracy: 0.9800
# Epoch 89/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2003 - accuracy: 0.9700 - val_loss: 0.1692 - val_accuracy: 0.9800
# Epoch 90/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1995 - accuracy: 0.9700 - val_loss: 0.1632 - val_accuracy: 0.9800
# Epoch 91/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1902 - accuracy: 0.9700 - val_loss: 0.1659 - val_accuracy: 0.9800
# Epoch 92/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1899 - accuracy: 0.9700 - val_loss: 0.1560 - val_accuracy: 0.9800
# Epoch 93/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1812 - accuracy: 0.9800 - val_loss: 0.1542 - val_accuracy: 0.9600
# Epoch 94/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1748 - accuracy: 0.9800 - val_loss: 0.1501 - val_accuracy: 0.9600
# Epoch 95/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1725 - accuracy: 0.9700 - val_loss: 0.1453 - val_accuracy: 0.9800
# Epoch 96/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1679 - accuracy: 0.9800 - val_loss: 0.1426 - val_accuracy: 0.9600
# Epoch 97/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1656 - accuracy: 0.9700 - val_loss: 0.1413 - val_accuracy: 0.9800
# Epoch 98/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1618 - accuracy: 0.9700 - val_loss: 0.1358 - val_accuracy: 0.9800
# Epoch 99/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9800 - val_loss: 0.1385 - val_accuracy: 0.9800
# Epoch 100/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1532 - accuracy: 0.9700 - val_loss: 0.1295 - val_accuracy: 0.9800

# %% [markdown]
# # 2. Bài tập về nhà :
#
# Huấn luyện mô hình neural network đối với cuộc thi phân loại thu nhập Income Classification
